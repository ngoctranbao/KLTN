# %%
import pandas as pd

# %%
# Đường dẫn đến tập dữ liệu CSV
file_path = "./../../datasets/Dataset_WOD.csv"

# %%
# Đọc tập dữ liệu từ file CSV vào DataFrame của pandas
df = pd.read_csv(file_path)

# %%
print("Thông tin cơ bản về tập dữ liệu:")
df.info()
# Out:
# Thông tin cơ bản về tập dữ liệu:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18296 entries, 0 to 18295
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   18296 non-null  object
#  1   label                                18296 non-null  bool
#  2   mint_count_per_week                  18296 non-null  float64
#  3   burn_count_per_week                  18296 non-null  float64
#  4   mint_ratio                           18296 non-null  float64
#  5   swap_ratio                           18296 non-null  float64
#  6   burn_ratio                           18296 non-null  float64
#  7   mint_mean_period                     18296 non-null  float64
#  8   swap_mean_period                     18296 non-null  float64
#  9   burn_mean_period                     18296 non-null  float64
#  10  swap_in_per_week                     18296 non-null  float64
#  11  swap_out_per_week                    18296 non-null  float64
#  12  swap_rate                            18296 non-null  float64
#  13  lp_avg                               18296 non-null  float64
#  14  lp_std                               18296 non-null  float64
#  15  lp_creator_holding_ratio             18296 non-null  float64
#  16  lp_lock_ratio                        18296 non-null  float64
#  17  token_burn_ratio                     18296 non-null  float64
#  18  token_creator_holding_ratio          18296 non-null  float64
#  19  number_of_token_creation_of_creator  18296 non-null  int64
# dtypes: bool(1), float64(17), int64(1), object(1)
# memory usage: 2.7+ MB

# %%
# Hiển thị 5 dòng đầu tiên của tập dữ liệu
print("\n5 dòng đầu tiên của tập dữ liệu:")
df.head()
# Out:
# 5 dòng đầu tiên của tập dữ liệu:
#                                            id  label  mint_count_per_week  \
# 0  0x3cd1c0b98be4451ca51265bbaeb76cf7b31e1c02  False            44.071475
# 1  0x0c52de7bb69edd144d58d772fab1cd196919f5ef  False            13.813171
# 2  0xa00d47b4b304792eb07b09233467b690db847c91  False            27.366327
# 3  0x114e40ba90e9d8b002bc6936e3299daa393017bb  False            10.559028
# 4  0x40829a59080a12f16bb8fba22354a6a42c810aab  False             9.662390
#
#    burn_count_per_week  mint_ratio  swap_ratio  burn_ratio  mint_mean_period  \
# 0            16.466820    0.148132    0.796520    0.055348          0.034508
# 1             6.316279    0.169770    0.752600    0.077630          0.040580
# 2            17.779613    0.068019    0.887790    0.044191          0.131459
# 3             1.912477    0.056257    0.933553    0.010189          0.036312
# 4             6.450369    0.024123    0.959774    0.016104          0.088733
#
#    swap_mean_period  burn_mean_period  swap_in_per_week  swap_out_per_week  \
# 0          0.074894          0.221980        100.871903         136.103828
# 1          0.050907          0.083953         42.502064          18.732391
# 2          0.384409          0.191228        165.965722         191.224332
# 3          0.077704          0.140362         90.398212          84.822399
# 4          0.206316          0.171454        204.911119         179.530891
#
#    swap_rate    lp_avg    lp_std  lp_creator_holding_ratio  lp_lock_ratio  \
# 0   0.741002  0.119760  0.126458              0.000000e+00       0.000000
# 1   2.266527  0.332226  0.431320              0.000000e+00       0.000000
# 2   0.867757  0.377358  4.649864              0.000000e+00       0.064726
# 3   1.065397  0.467290  4.754048              1.480000e-08       0.693921
# 4   1.141202  0.476190  5.466877              0.000000e+00       0.790202
#
#    token_burn_ratio  token_creator_holding_ratio  \
# 0      0.000000e+00                 1.302617e-01
# 1      4.000000e-07                 1.000000e-08
# 2      0.000000e+00                 0.000000e+00
# 3      3.748588e-03                 0.000000e+00
# 4      0.000000e+00                 1.000000e-08
#
#    number_of_token_creation_of_creator
# 0                                    1
# 1                                    1
# 2                                    1
# 3                                    1
# 4                                    1

# %%
# Hiển thị số lượng dòng và cột của tập dữ liệu
print("\nKích thước của tập dữ liệu:")
df.shape
# Out:
# Kích thước của tập dữ liệu:
# (18296, 20)

# %%
# Hiển thị một số đặc điểm thống kê của tập dữ liệu
print("\nMô tả thống kê của tập dữ liệu:")
df.describe()
# Out:
# Mô tả thống kê của tập dữ liệu:
#        mint_count_per_week  burn_count_per_week    mint_ratio    swap_ratio  \
# count         18296.000000         18296.000000  18296.000000  18296.000000
# mean              1.315291             0.147481      0.068256      0.927938
# std               4.778461             1.616996      0.075473      0.081730
# min               0.018679             0.000000      0.000095      0.000000
# 25%               0.934721             0.000000      0.018868      0.900000
# 50%               0.991913             0.000000      0.043478      0.954545
# 75%               0.998109             0.000000      0.100000      0.979592
# max             179.337185           174.699871      1.000000      0.999887
#
#          burn_ratio  mint_mean_period  swap_mean_period  burn_mean_period  \
# count  18296.000000      18296.000000      18296.000000      18296.000000
# mean       0.003806          0.019121          0.303362          0.052123
# std        0.023860          0.080289          0.192192          0.184001
# min        0.000000          0.000000          0.000000          0.000000
# 25%        0.000000          0.000000          0.142764          0.000000
# 50%        0.000000          0.000000          0.297689          0.000000
# 75%        0.000000          0.000000          0.436000          0.000000
# max        0.996875          0.910775          1.000000          1.000000
#
#        swap_in_per_week  swap_out_per_week     swap_rate        lp_avg  \
# count      18296.000000       18296.000000  18296.000000  18296.000000
# mean          34.189579          15.938667      9.009717     96.830431
# std           67.695251          44.314855     33.552226     14.551964
# min            0.000000           0.000000      0.000000      0.119760
# 25%            6.993438           0.990939      1.358562    100.000000
# 50%           16.724912           2.994892      3.000000    100.000000
# 75%           34.407108          10.786246      6.000000    100.000000
# max         1744.184937        1009.679001   1089.000000    100.000000
#
#              lp_std  lp_creator_holding_ratio  lp_lock_ratio  \
# count  18296.000000              18296.000000   1.829600e+04
# mean       1.732735                  0.845788   1.355621e-01
# std        8.369918                  0.358124   3.383333e-01
# min        0.000000                 -0.044800  -7.603275e-01
# 25%        0.000000                  1.000000  -1.807500e-14
# 50%        0.000000                  1.000000   0.000000e+00
# 75%        0.000000                  1.000000   5.320000e-11
# max       50.000000                  1.029160   1.044800e+00
#
#        token_burn_ratio  token_creator_holding_ratio  \
# count      18296.000000                 18296.000000
# mean           0.146746                     4.580812
# std            1.083602                   153.497881
# min            0.000000                  -500.000000
# 25%            0.000000                     0.000000
# 50%            0.000000                     0.020000
# 75%            0.109639                     0.400000
# max           99.439008                  6250.000000
#
#        number_of_token_creation_of_creator
# count                         18296.000000
# mean                              8.693321
# std                              33.846615
# min                               1.000000
# 25%                               1.000000
# 50%                               1.000000
# 75%                               2.000000
# max                             252.000000

# %%
# Đếm số lượng mẫu cho mỗi loại label
label_counts = df['Label'].value_counts()
label_counts
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Đếm số lượng mẫu cho mỗi loại label
# ----> 2 label_counts = df['Label'].value_counts()
#       3 label_counts
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Label'

# %%
    # Tính tỉ lệ của mỗi loại label
label_ratios = label_counts / label_counts.sum()
print(label_ratios)
# Out:
# True     0.89976
# False    0.10024
# Name: Label, dtype: float64
