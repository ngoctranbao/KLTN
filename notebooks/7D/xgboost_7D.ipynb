# %%
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from xgboost import XGBClassifier
import pandas as pd

label_encoder = LabelEncoder()

# %%
dataframe = pd.read_csv('./../../datasets/Dataset_7D.csv')
dataframe.dropna(inplace=True)
dataframe.rename(columns=lambda x : x.lower(), inplace=True)

dataframe['label'] = label_encoder.fit_transform(dataframe['label'])
print(dataframe.shape)
dataframe.head()
# Out:
# (12029, 20)
#                                            id  label  mint_count_per_week  \
# 0  0x3cd1c0b98be4451ca51265bbaeb76cf7b31e1c02      0           531.195902
# 1  0x0c52de7bb69edd144d58d772fab1cd196919f5ef      0            54.542476
# 2  0xa00d47b4b304792eb07b09233467b690db847c91      0           230.772631
# 3  0x114e40ba90e9d8b002bc6936e3299daa393017bb      0            58.779514
# 4  0x40829a59080a12f16bb8fba22354a6a42c810aab      0            94.726400
#
#    burn_count_per_week  mint_ratio  swap_ratio  burn_ratio  mint_mean_period  \
# 0            39.839693    0.481928    0.481928    0.036145          0.393718
# 1             2.001559    0.377163    0.608997    0.013841          0.805150
# 2           110.130106    0.274242    0.594884    0.130874          0.452930
# 3             8.540613    0.103175    0.881834    0.014991          0.759745
# 4            12.028749    0.155812    0.824402    0.019786          0.508112
#
#    swap_mean_period  burn_mean_period  swap_in_per_week  swap_out_per_week  \
# 0          0.032614          0.507770        304.375252         226.820650
# 1          0.640197          0.551141         49.038189          39.030396
# 2          0.053773          0.602639        240.784458         259.806931
# 3          0.190998          0.711122        318.012241         184.376765
# 4          0.002882          0.630434        313.248679         187.949207
#
#    swap_rate    lp_avg    lp_std  lp_creator_holding_ratio  lp_lock_ratio  \
# 0   1.338785  0.119760  0.126458              0.000000e+00       0.000000
# 1   1.240506  0.332226  0.431320              0.000000e+00       0.000000
# 2   0.925000  0.377358  4.649864              0.000000e+00       0.064726
# 3   1.720109  0.467290  4.754048              1.480000e-08       0.693921
# 4   1.662234  0.476190  5.466877              0.000000e+00       0.790202
#
#    token_burn_ratio  token_creator_holding_ratio  \
# 0      0.000000e+00                 1.302617e-01
# 1      4.000000e-07                 1.000000e-08
# 2      0.000000e+00                 0.000000e+00
# 3      3.748588e-03                 0.000000e+00
# 4      0.000000e+00                 1.000000e-08
#
#    number_of_token_creation_of_creator
# 0                                    1
# 1                                    1
# 2                                    1
# 3                                    1
# 4                                    1

# %%
x = dataframe.drop(columns=['id', 'label', 'number_of_token_creation_of_creator', 'token_creator_holding_ratio', 'lp_lock_ratio', 'lp_creator_holding_ratio'], axis=1)
y = dataframe['label']
scaler = StandardScaler().fit(x)
x = pd.DataFrame(scaler.transform(x))

x_train,x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

x_train = pd.DataFrame(x_train)
x_test = pd.DataFrame(x_test)
y_train = pd.DataFrame(y_train)
y_test = pd.DataFrame(y_test)

# %%
x_train
# Out:
#              0         1         2         3         4         5         6   \
# 5875  -0.107553 -0.373485  0.999970 -0.292434 -0.872662 -0.311578  0.306057
# 3562  -0.084572 -0.146657 -0.755394  0.907808 -0.843623  0.157796 -0.787677
# 3003  -0.057395  0.285934 -0.756348  0.895855 -0.816027  1.697512 -1.037412
# 2140  -0.115616 -0.154877 -0.773208  0.919166 -0.841528 -0.311578 -0.910866
# 9790  -0.093042  0.016037  0.775750 -1.222480  1.501295 -0.311578 -0.297219
# ...         ...       ...       ...       ...       ...       ...       ...
# 11964 -0.092968  0.016600  0.043297 -0.209763  0.393448 -0.311578  1.262226
# 5191  -0.093146  0.015253 -0.345352  0.327596 -0.194389 -0.311578  0.397921
# 5390  -0.093149  0.015233  0.601356 -0.981357  1.237522 -0.311578 -0.945450
# 860   -0.055764  0.634160 -0.705678  0.795339 -0.672750  4.205377  1.660366
# 7270  -0.099367 -0.031848 -0.291539  0.253193 -0.112996 -0.311578 -0.990121
#
#              7         8         9         10        11        12        13
# 5875  -1.581330 -0.510263 -0.433652 -0.214534  0.272012 -0.258220 -0.131737
# 3562  -1.258252  1.497229  2.001865 -0.216610  0.272012 -0.258220 -0.091397
# 3003  -0.176884  3.655513  1.419841 -0.152459  0.272012 -0.258220  0.053304
# 2140  -0.563239  1.552794  1.360122 -0.201908  0.272012 -0.258220  0.112085
# 9790   0.730454 -0.480230 -0.454759 -0.075018  0.272012 -0.258220  0.282927
# ...         ...       ...       ...       ...       ...       ...       ...
# 11964  0.730454 -0.432072 -0.425318 -0.144776  0.272012 -0.258220  0.282927
# 5191   0.730454 -0.336622 -0.381411 -0.149759  0.272012 -0.258220  0.324393
# 5390   0.730454 -0.509092 -0.396083 -0.236458  0.272012 -0.258220 -0.131737
# 860   -0.157518  1.341447  0.217014 -0.128720 -2.549174  4.640671 -0.131737
# 7270   0.730454 -0.361002 -0.428974 -0.045122  0.272012 -0.258220  0.141941
#
# [9623 rows x 14 columns]

# %%
xgboost_model = XGBClassifier(objective="binary:logistic", n_estimators=20, random_state=42, eval_metric=["auc", "error", "error@0.6"])

# %%
xgboost_model.fit(x_train, y_train, eval_set=[(x_test, y_test)])
# Out:
# [0]	validation_0-auc:0.94979	validation_0-error:0.15461	validation_0-error@0.6:0.10017
# [1]	validation_0-auc:0.95819	validation_0-error:0.10141	validation_0-error@0.6:0.08770
# [2]	validation_0-auc:0.96032	validation_0-error:0.09518	validation_0-error@0.6:0.08645
# [3]	validation_0-auc:0.96065	validation_0-error:0.09227	validation_0-error@0.6:0.08811
# [4]	validation_0-auc:0.96191	validation_0-error:0.08687	validation_0-error@0.6:0.08645
# [5]	validation_0-auc:0.96280	validation_0-error:0.08728	validation_0-error@0.6:0.08603
# [6]	validation_0-auc:0.96385	validation_0-error:0.08437	validation_0-error@0.6:0.08562
# [7]	validation_0-auc:0.96442	validation_0-error:0.08146	validation_0-error@0.6:0.08687
# [8]	validation_0-auc:0.96547	validation_0-error:0.08229	validation_0-error@0.6:0.08645
# [9]	validation_0-auc:0.96572	validation_0-error:0.08146	validation_0-error@0.6:0.08396
# [10]	validation_0-auc:0.96574	validation_0-error:0.08188	validation_0-error@0.6:0.08479
# [11]	validation_0-auc:0.96553	validation_0-error:0.08479	validation_0-error@0.6:0.08479
# [12]	validation_0-auc:0.96550	validation_0-error:0.08146	validation_0-error@0.6:0.08645
# [13]	validation_0-auc:0.96581	validation_0-error:0.07855	validation_0-error@0.6:0.08520
# [14]	validation_0-auc:0.96561	validation_0-error:0.07855	validation_0-error@0.6:0.08603
# [15]	validation_0-auc:0.96626	validation_0-error:0.07689	validation_0-error@0.6:0.08479
# [16]	validation_0-auc:0.96630	validation_0-error:0.07814	validation_0-error@0.6:0.08520
# [17]	validation_0-auc:0.96633	validation_0-error:0.07814	validation_0-error@0.6:0.08728
# [18]	validation_0-auc:0.96640	validation_0-error:0.07814	validation_0-error@0.6:0.08437
# [19]	validation_0-auc:0.96647	validation_0-error:0.07814	validation_0-error@0.6:0.08479
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False,
#               eval_metric=['auc', 'error', 'error@0.6'], feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=20, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
y_pred = xgboost_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score
print("Accuracy: ", accuracy_score(y_pred, y_test))
print("Precision: ", precision_score(y_pred, y_test))
print("Recall: ", recall_score(y_pred, y_test))
print("F1: ", f1_score(y_pred, y_test))
# Out:
# Accuracy:  0.9218620116375728
# Precision:  0.9611602753195674
# Recall:  0.9471899224806202
# F1:  0.954123962908736
# F1:  0.954123962908736
