# %%
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from xgboost import XGBClassifier
import pandas as pd

label_encoder = LabelEncoder()

# %%
dataframe = pd.read_csv('./../../datasets/Dataset_7D.csv')

dataframe.dropna(inplace=True)
dataframe.rename(columns=lambda x : x.lower(), inplace=True)

dataframe['label'] = label_encoder.fit_transform(dataframe['label'])
print(dataframe.shape)
dataframe.head()
# Out:
# (19750, 20)
#                                            id  label  mint_count_per_week  \
# 0  0x3cd1c0b98be4451ca51265bbaeb76cf7b31e1c02      0            44.071475
# 1  0x0c52de7bb69edd144d58d772fab1cd196919f5ef      0            13.813171
# 2  0xa00d47b4b304792eb07b09233467b690db847c91      0            27.366327
# 3  0x114e40ba90e9d8b002bc6936e3299daa393017bb      0            10.559028
# 4  0x40829a59080a12f16bb8fba22354a6a42c810aab      0             9.662390
#
#    burn_count_per_week  mint_ratio  swap_ratio  burn_ratio  mint_mean_period  \
# 0            16.466820    0.148132    0.796520    0.055348          0.034508
# 1             6.316279    0.169770    0.752600    0.077630          0.040580
# 2            17.779613    0.068019    0.887790    0.044191          0.131459
# 3             1.912477    0.056257    0.933553    0.010189          0.036312
# 4             6.450369    0.024123    0.959774    0.016104          0.088733
#
#    swap_mean_period  burn_mean_period  swap_in_per_week  swap_out_per_week  \
# 0          0.074894          0.221980        100.871903         136.103828
# 1          0.050907          0.083953         42.502064          18.732391
# 2          0.384409          0.191228        165.965722         191.224332
# 3          0.077704          0.140362         90.398212          84.822399
# 4          0.206316          0.171454        204.911119         179.530891
#
#    swap_rate    lp_avg    lp_std  lp_creator_holding_ratio  lp_lock_ratio  \
# 0   0.741002  0.119760  0.126458              0.000000e+00       0.000000
# 1   2.266527  0.332226  0.431320              0.000000e+00       0.000000
# 2   0.867757  0.377358  4.649864              0.000000e+00       0.064726
# 3   1.065397  0.467290  4.754048              1.480000e-08       0.693921
# 4   1.141202  0.476190  5.466877              0.000000e+00       0.790202
#
#    token_burn_ratio  token_creator_holding_ratio  \
# 0      0.000000e+00                 1.302617e-01
# 1      4.000000e-07                 1.000000e-08
# 2      0.000000e+00                 0.000000e+00
# 3      3.748588e-03                 0.000000e+00
# 4      0.000000e+00                 1.000000e-08
#
#    number_of_token_creation_of_creator
# 0                                    1
# 1                                    1
# 2                                    1
# 3                                    1
# 4                                    1

# %%
x = dataframe.drop(columns=['id', 'label'], axis=1)
y = dataframe['label']
scaler = StandardScaler().fit(x)
x = pd.DataFrame(scaler.transform(x))

x_train,x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

x_train = pd.DataFrame(x_train)
x_test = pd.DataFrame(x_test)
y_train = pd.DataFrame(y_train)
y_test = pd.DataFrame(y_test)

# %%
x_train
# Out:
#              0         1         2         3         4         5         6   \
# 15975 -0.034306 -0.059021 -0.382775  0.407291 -0.195884 -0.298136  0.229524
# 5770  -0.036765 -0.059021  0.438776 -0.343316 -0.195884 -0.298136  1.148430
# 6202  -0.030550 -0.059021 -0.493236  0.508213 -0.195884 -0.298136 -0.069900
# 10371 -0.035121 -0.059021  0.997983 -0.854233 -0.195884 -0.298136 -0.591581
# 2556  -0.030179 -0.059021 -0.458285  0.476281 -0.195884 -0.298136 -0.362778
# ...         ...       ...       ...       ...       ...       ...       ...
# 11284 -0.029898 -0.059021  0.065971 -0.002704 -0.195884 -0.298136  1.543414
# 11964 -0.029954 -0.059021  0.065971 -0.002704 -0.195884 -0.298136  0.628574
# 5390  -0.029893 -0.059021  0.764980 -0.641351 -0.195884 -0.298136 -0.397127
# 860    0.002085  0.371458 -0.774152  0.680918  0.089769  4.970739  0.898149
# 15795 -0.030071 -0.059021  1.308654 -1.138076 -0.195884 -0.298136  1.798406
#
#              7         8         9         10        11        12        13  \
# 15975 -0.343848 -0.210963 -0.150726 -0.065830  0.300636 -0.281509 -0.004109
# 5770  -0.343848 -0.296183 -0.195739 -0.021156  0.300636 -0.281509 -0.004109
# 6202  -0.343848 -0.134670 -0.139450 -0.062364  0.300636 -0.281509 -0.004109
# 10371 -0.343848 -0.324823 -0.189440 -0.064987  0.300636 -0.281509 -0.004109
# 2556  -0.343848 -0.123807 -0.167355 -0.045431  0.300636 -0.281509 -0.223632
# ...         ...       ...       ...       ...       ...       ...       ...
# 11284 -0.343848 -0.247800 -0.195739  0.005817  0.300636 -0.281509 -0.004109
# 11964 -0.343848 -0.265858 -0.181474 -0.057120  0.300636 -0.281509 -0.004109
# 5390  -0.343848 -0.337465 -0.167171 -0.077799  0.300636 -0.281509 -0.004109
# 860    1.815245  1.388461  0.130202 -0.053498 -2.112196  2.994307 -0.004109
# 15795 -0.343848 -0.319709 -0.195739 -0.048129  0.300636 -0.281509 -0.004109
#
#              14        15        16        17
# 15975 -0.154666 -0.149491 -0.027083 -0.187725
# 5770  -0.154666 -0.149491 -0.029054 -0.126446
# 6202  -0.154666 -0.149491 -0.024066 -0.218364
# 10371 -0.154666 -0.149124 -0.024920 -0.218364
# 2556  -0.081814 -0.149491 -0.023500 -0.218364
# ...         ...       ...       ...       ...
# 11284 -0.154666 -0.149491 -0.029731  4.561354
# 11964 -0.154666 -0.112253 -0.029731 -0.218364
# 5390  -0.154666 -0.149491 -0.022970 -0.218364
# 860   -0.154666 -0.149491 -0.024896 -0.218364
# 15795 -0.154666 -0.149491 -0.025576 -0.218364
#
# [15800 rows x 18 columns]

# %%
xgboost_model = XGBClassifier(objective="binary:logistic", n_estimators=20, random_state=42, eval_metric=["auc", "error", "error@0.6"])

# %%
xgboost_model.fit(x_train, y_train, eval_set=[(x_test, y_test)])
# Out:
# [0]	validation_0-auc:0.97726	validation_0-error:0.15570	validation_0-error@0.6:0.02937
# [1]	validation_0-auc:0.98395	validation_0-error:0.02405	validation_0-error@0.6:0.02532
# [2]	validation_0-auc:0.98521	validation_0-error:0.02405	validation_0-error@0.6:0.02354
# [3]	validation_0-auc:0.98698	validation_0-error:0.02481	validation_0-error@0.6:0.02253
# [4]	validation_0-auc:0.98770	validation_0-error:0.02405	validation_0-error@0.6:0.02228
# [5]	validation_0-auc:0.98833	validation_0-error:0.02228	validation_0-error@0.6:0.02177
# [6]	validation_0-auc:0.98868	validation_0-error:0.02253	validation_0-error@0.6:0.02177
# [7]	validation_0-auc:0.99136	validation_0-error:0.02203	validation_0-error@0.6:0.02177
# [8]	validation_0-auc:0.99179	validation_0-error:0.02101	validation_0-error@0.6:0.02177
# [9]	validation_0-auc:0.99223	validation_0-error:0.02101	validation_0-error@0.6:0.02177
# [10]	validation_0-auc:0.99253	validation_0-error:0.02101	validation_0-error@0.6:0.02177
# [11]	validation_0-auc:0.99331	validation_0-error:0.01975	validation_0-error@0.6:0.02076
# [12]	validation_0-auc:0.99294	validation_0-error:0.01975	validation_0-error@0.6:0.02051
# [13]	validation_0-auc:0.99289	validation_0-error:0.02025	validation_0-error@0.6:0.02101
# [14]	validation_0-auc:0.99261	validation_0-error:0.01949	validation_0-error@0.6:0.02076
# [15]	validation_0-auc:0.99272	validation_0-error:0.01924	validation_0-error@0.6:0.02000
# [16]	validation_0-auc:0.99322	validation_0-error:0.01949	validation_0-error@0.6:0.02000
# [17]	validation_0-auc:0.99335	validation_0-error:0.01949	validation_0-error@0.6:0.01975
# [18]	validation_0-auc:0.99314	validation_0-error:0.01949	validation_0-error@0.6:0.01975
# [19]	validation_0-auc:0.99325	validation_0-error:0.01975	validation_0-error@0.6:0.01949
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False,
#               eval_metric=['auc', 'error', 'error@0.6'], feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=20, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
y_pred = xgboost_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score
print("Accuracy: ", accuracy_score(y_pred, y_test))
print("Precision: ", precision_score(y_pred, y_test))
print("Recall: ", recall_score(y_pred, y_test))
print("F1: ", f1_score(y_pred, y_test))
# Out:
# Accuracy:  0.980253164556962
# Precision:  0.9889055472263868
# Recall:  0.9877208745133274
# F1:  0.9883128558585556
