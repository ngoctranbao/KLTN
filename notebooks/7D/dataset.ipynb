# %%
import pandas as pd

# %%
# Đường dẫn đến tập dữ liệu CSV
file_path = "./../../datasets/Dataset_7D.csv"

# %%
# Đọc tập dữ liệu từ file CSV vào DataFrame của pandas
df = pd.read_csv(file_path)

# %%
print("Thông tin cơ bản về tập dữ liệu:")
df.info()
# Out:
# Thông tin cơ bản về tập dữ liệu:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12029 entries, 0 to 12028
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   12029 non-null  object
#  1   label                                12029 non-null  bool
#  2   mint_count_per_week                  12029 non-null  float64
#  3   burn_count_per_week                  12029 non-null  float64
#  4   mint_ratio                           12029 non-null  float64
#  5   swap_ratio                           12029 non-null  float64
#  6   burn_ratio                           12029 non-null  float64
#  7   mint_mean_period                     12029 non-null  float64
#  8   swap_mean_period                     12029 non-null  float64
#  9   burn_mean_period                     12029 non-null  float64
#  10  swap_in_per_week                     12029 non-null  float64
#  11  swap_out_per_week                    12029 non-null  float64
#  12  swap_rate                            12029 non-null  float64
#  13  lp_avg                               12029 non-null  float64
#  14  lp_std                               12029 non-null  float64
#  15  lp_creator_holding_ratio             12029 non-null  float64
#  16  lp_lock_ratio                        12029 non-null  float64
#  17  token_burn_ratio                     12029 non-null  float64
#  18  token_creator_holding_ratio          12029 non-null  float64
#  19  number_of_token_creation_of_creator  12029 non-null  int64
# dtypes: bool(1), float64(17), int64(1), object(1)
# memory usage: 1.8+ MB

# %%
# Hiển thị 5 dòng đầu tiên của tập dữ liệu
print("\n5 dòng đầu tiên của tập dữ liệu:")
df.head()
# Out:
# 5 dòng đầu tiên của tập dữ liệu:
#                                            id  label  mint_count_per_week  \
# 0  0x3cd1c0b98be4451ca51265bbaeb76cf7b31e1c02  False           531.195902
# 1  0x0c52de7bb69edd144d58d772fab1cd196919f5ef  False            54.542476
# 2  0xa00d47b4b304792eb07b09233467b690db847c91  False           230.772631
# 3  0x114e40ba90e9d8b002bc6936e3299daa393017bb  False            58.779514
# 4  0x40829a59080a12f16bb8fba22354a6a42c810aab  False            94.726400
#
#    burn_count_per_week  mint_ratio  swap_ratio  burn_ratio  mint_mean_period  \
# 0            39.839693    0.481928    0.481928    0.036145          0.393718
# 1             2.001559    0.377163    0.608997    0.013841          0.805150
# 2           110.130106    0.274242    0.594884    0.130874          0.452930
# 3             8.540613    0.103175    0.881834    0.014991          0.759745
# 4            12.028749    0.155812    0.824402    0.019786          0.508112
#
#    swap_mean_period  burn_mean_period  swap_in_per_week  swap_out_per_week  \
# 0          0.032614          0.507770        304.375252         226.820650
# 1          0.640197          0.551141         49.038189          39.030396
# 2          0.053773          0.602639        240.784458         259.806931
# 3          0.190998          0.711122        318.012241         184.376765
# 4          0.002882          0.630434        313.248679         187.949207
#
#    swap_rate    lp_avg    lp_std  lp_creator_holding_ratio  lp_lock_ratio  \
# 0   1.338785  0.119760  0.126458              0.000000e+00       0.000000
# 1   1.240506  0.332226  0.431320              0.000000e+00       0.000000
# 2   0.925000  0.377358  4.649864              0.000000e+00       0.064726
# 3   1.720109  0.467290  4.754048              1.480000e-08       0.693921
# 4   1.662234  0.476190  5.466877              0.000000e+00       0.790202
#
#    token_burn_ratio  token_creator_holding_ratio  \
# 0      0.000000e+00                 1.302617e-01
# 1      4.000000e-07                 1.000000e-08
# 2      0.000000e+00                 0.000000e+00
# 3      3.748588e-03                 0.000000e+00
# 4      0.000000e+00                 1.000000e-08
#
#    number_of_token_creation_of_creator
# 0                                    1
# 1                                    1
# 2                                    1
# 3                                    1
# 4                                    1

# %%
# Hiển thị số lượng dòng và cột của tập dữ liệu
print("\nKích thước của tập dữ liệu:")
df.shape
# Out:
# Kích thước của tập dữ liệu:
# (12029, 20)

# %%
# Hiển thị một số đặc điểm thống kê của tập dữ liệu
print("\nMô tả thống kê của tập dữ liệu:")
df.describe()
# Out:
# Mô tả thống kê của tập dữ liệu:
#        mint_count_per_week  burn_count_per_week    mint_ratio    swap_ratio  \
# count         12029.000000         12029.000000  12029.000000  12029.000000
# mean              2.798573             0.955440      0.063218      0.890832
# std              19.369474             2.558283      0.079644      0.115206
# min               0.000000             0.000000      0.000994      0.000000
# 25%               0.874523             0.533148      0.016129      0.837288
# 50%               0.978672             0.943440      0.040000      0.925926
# 75%               0.998002             0.995167      0.083333      0.975000
# max             847.501566           119.074069      1.000000      0.999001
#
#          burn_ratio  mint_mean_period  swap_mean_period  burn_mean_period  \
# count  12029.000000      12029.000000      12029.000000      12029.000000
# mean       0.045950          0.033840          0.184412          0.684030
# std        0.052657          0.108614          0.168935          0.432584
# min        0.000000          0.000000          0.000000          0.000000
# 25%        0.001986          0.000000          0.049596          0.102251
# 50%        0.029412          0.000000          0.128397          1.000000
# 75%        0.071429          0.000000          0.285126          1.000000
# max        0.555556          0.953933          1.000000          1.000000
#
#        swap_in_per_week  swap_out_per_week     swap_rate        lp_avg  \
# count      12029.000000       12029.000000  12029.000000  12029.000000
# mean          55.821266          30.828442      8.509270     95.179115
# std          103.793188          67.793606     33.450345     17.723776
# min            0.000000           0.000000      0.000000      0.119760
# 25%            7.986860           0.993745      1.333333    100.000000
# 50%           18.800472           3.970634      2.625000    100.000000
# 75%           46.582468          17.926231      5.500000    100.000000
# max          993.874332         492.541099   1000.000000    100.000000
#
#              lp_std  lp_creator_holding_ratio  lp_lock_ratio  \
# count  12029.000000              12029.000000   1.202900e+04
# mean       2.635475                  0.765429   2.062036e-01
# std       10.206739                  0.419789   3.994270e-01
# min        0.000000                 -0.044800  -7.603275e-01
# 25%        0.000000                  0.990000   0.000000e+00
# 50%        0.000000                  1.000000   9.090000e-13
# 75%        0.000000                  1.000000   5.999277e-03
# max       50.000000                  1.006711   1.044800e+00
#
#        token_burn_ratio  token_creator_holding_ratio  \
# count      12029.000000                 1.202900e+04
# mean           0.158848                 6.600465e+00
# std            1.205845                 1.882231e+02
# min            0.000000                -5.000000e+02
# 25%            0.000000                 0.000000e+00
# 50%            0.000000                 5.420000e-07
# 75%            0.158594                 2.418202e-01
# max           99.439008                 6.250000e+03
#
#        number_of_token_creation_of_creator
# count                         12029.000000
# mean                             10.440685
# std                              39.644327
# min                               1.000000
# 25%                               1.000000
# 50%                               1.000000
# 75%                               1.000000
# max                             252.000000

# %%
# Đếm số lượng mẫu cho mỗi loại label
label_counts = df['label'].value_counts()
label_counts
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Đếm số lượng mẫu cho mỗi loại label
# ----> 2 label_counts = df['Label'].value_counts()
#       3 label_counts
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Label'

# %%
# Tính tỉ lệ của mỗi loại label
label_ratios = label_counts / label_counts.sum()
print(label_ratios)
# Out:
# True     0.854352
# False    0.145648
# Name: Label, dtype: float64
