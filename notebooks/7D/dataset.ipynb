# %%
import pandas as pd

# %%
# Đường dẫn đến tập dữ liệu CSV
file_path = "./../../datasets/Dataset_7D.csv"

# %%
# Đọc tập dữ liệu từ file CSV vào DataFrame của pandas
df = pd.read_csv(file_path)

# %%
print("Thông tin cơ bản về tập dữ liệu:")
df.info()
# Out:
# Thông tin cơ bản về tập dữ liệu:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14862 entries, 0 to 14861
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   14862 non-null  object
#  1   label                                14862 non-null  bool
#  2   mint_count_per_week                  14862 non-null  float64
#  3   burn_count_per_week                  14862 non-null  float64
#  4   mint_ratio                           14862 non-null  float64
#  5   swap_ratio                           14862 non-null  float64
#  6   burn_ratio                           14862 non-null  float64
#  7   mint_mean_period                     14862 non-null  float64
#  8   swap_mean_period                     14862 non-null  float64
#  9   burn_mean_period                     14862 non-null  float64
#  10  swap_in_per_week                     14862 non-null  float64
#  11  swap_out_per_week                    14862 non-null  float64
#  12  swap_rate                            14862 non-null  float64
#  13  lp_avg                               14862 non-null  float64
#  14  lp_std                               14862 non-null  float64
#  15  lp_creator_holding_ratio             14862 non-null  float64
#  16  lp_lock_ratio                        14862 non-null  float64
#  17  token_burn_ratio                     14862 non-null  float64
#  18  token_creator_holding_ratio          14862 non-null  float64
#  19  number_of_token_creation_of_creator  14862 non-null  int64
# dtypes: bool(1), float64(17), int64(1), object(1)
# memory usage: 2.2+ MB

# %%
# Hiển thị 5 dòng đầu tiên của tập dữ liệu
print("\n5 dòng đầu tiên của tập dữ liệu:")
df.head()
# Out:
# 5 dòng đầu tiên của tập dữ liệu:
#                                            id  label  mint_count_per_week  \
# 0  0x3cd1c0b98be4451ca51265bbaeb76cf7b31e1c02  False           531.195902
# 1  0x0c52de7bb69edd144d58d772fab1cd196919f5ef  False            54.542476
# 2  0xa00d47b4b304792eb07b09233467b690db847c91  False           230.772631
# 3  0x114e40ba90e9d8b002bc6936e3299daa393017bb  False            58.779514
# 4  0x40829a59080a12f16bb8fba22354a6a42c810aab  False            94.726400
#
#    burn_count_per_week  mint_ratio  swap_ratio  burn_ratio  mint_mean_period  \
# 0            39.839693    0.481928    0.481928    0.036145          0.393718
# 1             2.001559    0.377163    0.608997    0.013841          0.805150
# 2           110.130106    0.274242    0.594884    0.130874          0.452930
# 3             8.540613    0.103175    0.881834    0.014991          0.759745
# 4            12.028749    0.155812    0.824402    0.019786          0.508112
#
#    swap_mean_period  burn_mean_period  swap_in_per_week  swap_out_per_week  \
# 0          0.032614          0.507770        304.375252         226.820650
# 1          0.640197          0.551141         49.038189          39.030396
# 2          0.053773          0.602639        240.784458         259.806931
# 3          0.190998          0.711122        318.012241         184.376765
# 4          0.002882          0.630434        313.248679         187.949207
#
#    swap_rate    lp_avg    lp_std  lp_creator_holding_ratio  lp_lock_ratio  \
# 0   1.338785  0.119760  0.126458              0.000000e+00       0.000000
# 1   1.240506  0.332226  0.431320              0.000000e+00       0.000000
# 2   0.925000  0.377358  4.649864              0.000000e+00       0.064726
# 3   1.720109  0.467290  4.754048              1.480000e-08       0.693921
# 4   1.662234  0.476190  5.466877              0.000000e+00       0.790202
#
#    token_burn_ratio  token_creator_holding_ratio  \
# 0      0.000000e+00                 1.302617e-01
# 1      4.000000e-07                 1.000000e-08
# 2      0.000000e+00                 0.000000e+00
# 3      3.748588e-03                 0.000000e+00
# 4      0.000000e+00                 1.000000e-08
#
#    number_of_token_creation_of_creator
# 0                                    1
# 1                                    1
# 2                                    1
# 3                                    1
# 4                                    1

# %%
# Hiển thị số lượng dòng và cột của tập dữ liệu
print("\nKích thước của tập dữ liệu:")
df.shape
# Out:
# Kích thước của tập dữ liệu:
# (14862, 20)

# %%
# Hiển thị một số đặc điểm thống kê của tập dữ liệu
print("\nMô tả thống kê của tập dữ liệu:")
df.describe()
# Out:
# Mô tả thống kê của tập dữ liệu:
#        mint_count_per_week  burn_count_per_week    mint_ratio    swap_ratio  \
# count         14862.000000         14862.000000  14862.000000  14862.000000
# mean              4.157797             1.087327      0.063855      0.895286
# std              28.235395             4.030138      0.087837      0.119163
# min               0.000000             0.000000      0.000095      0.000000
# 25%               0.828277             0.080550      0.012500      0.846154
# 50%               0.979684             0.919791      0.037037      0.934754
# 75%               0.998976             0.995439      0.083333      0.980392
# max            1079.223666           179.870611      1.000000      0.999887
#
#          burn_ratio  mint_mean_period  swap_mean_period  burn_mean_period  \
# count  14862.000000      14862.000000      14862.000000      14862.000000
# mean       0.040859          0.053351          0.186329          0.610049
# std        0.050914          0.128305          0.173291          0.441262
# min        0.000000          0.000000          0.000000          0.000000
# 25%        0.000998          0.000000          0.046993          0.037967
# 50%        0.022727          0.000000          0.129012          0.995930
# 75%        0.062500          0.006366          0.291710          1.000000
# max        0.555556          0.953933          1.000000          1.000000
#
#        swap_in_per_week  swap_out_per_week     swap_rate        lp_avg  \
# count      14862.000000       14862.000000  14862.000000  14862.000000
# mean          62.635876          38.589931      9.720071     87.411419
# std          118.751546          91.800913    124.458669     27.921296
# min            0.000000           0.000000      0.000000      0.119760
# 25%            8.332921           1.423538      1.100000    100.000000
# 50%           19.009229           5.294200      2.000000    100.000000
# 75%           51.843195          27.398849      4.675676    100.000000
# max         2266.401062        3311.288181   6000.000000    100.000000
#
#              lp_std  lp_creator_holding_ratio  lp_lock_ratio  \
# count  14862.000000              14862.000000   1.486200e+04
# mean       7.899214                  0.868860   1.032719e+00
# std       18.886300                  4.562152   8.649021e+00
# min        0.000000                 -0.044800  -7.603275e-01
# 25%        0.000000                  0.000000   0.000000e+00
# 50%        0.000000                  1.000000   7.265000e-13
# 75%        0.000000                  1.000000   2.192807e-01
# max       96.814410                100.000000   1.000000e+02
#
#        token_burn_ratio  token_creator_holding_ratio  \
# count      1.486200e+04                 1.486200e+04
# mean       6.728570e+22                -6.728570e+22
# std        8.202786e+24                 8.202786e+24
# min        0.000000e+00                -1.000000e+27
# 25%        0.000000e+00                 0.000000e+00
# 50%        0.000000e+00                 0.000000e+00
# 75%        1.414844e-01                 1.657182e-01
# max        1.000000e+27                 6.250000e+03
#
#        number_of_token_creation_of_creator
# count                         14862.000000
# mean                              8.891334
# std                              36.436648
# min                               1.000000
# 25%                               1.000000
# 50%                               1.000000
# 75%                               1.000000
# max                             252.000000

# %%
# Đếm số lượng mẫu cho mỗi loại label
label_counts = df['label'].value_counts()
label_counts
# Out:
# True     10883
# False     3979
# Name: label, dtype: int64

# %%
# Tính tỉ lệ của mỗi loại label
label_ratios = label_counts / label_counts.sum()
print(label_ratios)
# Out:
# True     0.73227
# False    0.26773
# Name: label, dtype: float64
